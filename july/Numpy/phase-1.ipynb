# %% [markdown]
# ### Numpy array and basics
# learn about python with chai aur code

# %%
import numpy as np

# %%
## Creating array from list
arr_1d = np.array([1, 2, 3, 4, 5])
print("1D array:\n",arr_1d)

arr_2d= np.array([[1, 2, 3], [4, 5, 6]])
print("2D array:\n", arr_2d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 ## Creating array from list
# ----> 2 arr_1d = np.array([1, 2, 3, 4, 5])
#       3 print("1D array:\n",arr_1d)
#       5 arr_2d= np.array([[1, 2, 3], [4, 5, 6]])
#
# TypeError: 'numpy.ndarray' object is not callable

# %% [markdown]
# ### List vs Numpy array

# %%
py_list=[1,2,3]
print("Python list multiplied by 2:", py_list*2) #repeats the list elements two times
#its a very easy multiplication


np_array = np.array([1, 2, 3])
print("Numpy array multiplied by 2:", np_array * 2)  # Correct: Multiplies each element by
# Out:
# Python list multiplied by 2: [1, 2, 3, 1, 2, 3]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 6
#       2 print("Python list multiplied by 2:", py_list*2) #repeats the list elements two times
#       3 #its a very easy multiplication
# ----> 6 np_array = np.array([1, 2, 3])
#       7 print("Numpy array multiplied by 2:", np_array * 2)  # Correct: Multiplies each element by
#
# TypeError: 'numpy.ndarray' object is not callable
